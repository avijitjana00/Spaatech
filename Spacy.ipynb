# %%
pip install spacy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2022-03-24 08:14:38.987047: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-03-24 08:14:38.987216: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
with open("sample3.txt","r") as f:
    text = f.read()

# %%
print(text)
# Out:
# Quod equidem non reprehendo;
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti; Quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero. Duo Reges: constructio interrete. Tum Lucius: Mihi vero ista valde probata sunt, quod item fratri puto. Bestiarum vero nullum iudicium puto. Nihil enim iam habes, quod ad corpus referas; Deinde prima illa, quae in congressu solemus: Quid tu, inquit, huc? Et homini, qui ceteris animantibus plurimum praestat, praecipue a natura nihil datum esse dicemus?
#
# ...

# %%
doc = nlp(text)

# %%
print(doc)
# Out:
# Quod equidem non reprehendo;
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti; Quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero. Duo Reges: constructio interrete. Tum Lucius: Mihi vero ista valde probata sunt, quod item fratri puto. Bestiarum vero nullum iudicium puto. Nihil enim iam habes, quod ad corpus referas; Deinde prima illa, quae in congressu solemus: Quid tu, inquit, huc? Et homini, qui ceteris animantibus plurimum praestat, praecipue a natura nihil datum esse dicemus?
#
# ...

# %%
print(len(text))
print(len(doc))
# Out:
# 3541
# 696

# %%
for token in text[:12]:
    print(token)
# Out:
# Q
# u
# o
# d
#
# e
# q
# u
# i
# d
# e
# m

# %%
for token in doc[:12]:
    print(token)
# Out:
# Quod
# equidem
# non
# reprehendo
# ;
#
#
# Lorem
# ipsum
# dolor
# sit
# amet
# ,

# %%
for token in text.split()[:12]:
    print(token)
# Out:
# Quod
# equidem
# non
# reprehendo;
# Lorem
# ipsum
# dolor
# sit
# amet,
# consectetur
# adipiscing
# elit.

# %%
## SBD - sentenceboundary detection

# %%
for sent in doc.sents:
    print(sent)
# Out:
# Quod equidem non reprehendo;
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
# Quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti; Quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero.
# Duo Reges: constructio interrete.
# Tum Lucius: Mihi vero ista valde probata sunt, quod item fratri puto.
# Bestiarum vero nullum iudicium puto.
# Nihil enim iam habes, quod ad corpus referas; Deinde prima illa, quae in congressu solemus: Quid tu, inquit, huc?
# Et homini, qui ceteris animantibus plurimum praestat, praecipue a natura nihil datum esse dicemus?
#
#
# Iam id ipsum absurdum, maximum malum neglegi.
# Quod ea non occurrentia fingunt, vincunt Aristonem; Atqui perspicuum est hominem e corpore animoque constare, cum primae sint animi partes, secundae corporis.
# Fieri, inquam, Triari, nullo pacto potest, ut non dicas, quid non probes eius, a quo dissentias.
# Equidem e Cn.
# ...

# %%
senntece1 = doc.sents[0]
print(sentence1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-ea5910083089> in <module>
# ----> 1 senntece1 = doc.sents[0]
#       2 print(sentence1)
#
# TypeError: 'generator' object is not subscriptable

# %%
sentence1 = list(doc.sents)[1]
print(sentence1)
# Out:
# Quibus natura iure responderit non esse verum aliunde finem beate vivendi, a se principia rei gerendae peti; Quae enim adhuc protulisti, popularia sunt, ego autem a te elegantiora desidero.

# %%
for token in doc[:12]:
    print(token)
# Out:
# Quod
# equidem
# non
# reprehendo
# ;
#
#
# Lorem
# ipsum
# dolor
# sit
# amet
# ,

# %%
token2 = sentence1[1]
print(token2)
# Out:
# natura

# %%
token2.text
# Out:
# 'natura'

# %%
token2.left_edge
# Out:
# natura

# %%
token2.right_edge
# Out:
# natura

# %%
token2.ent_type
# Out:
# 0

# %%
token2.ent_type_
# Out:
# ''

# %%
token2.ent_iob_
# Out:
# 'O'

# %%
token2.lemma_
# Out:
# 'natura'

# %%
token2.morph
# Out:
# Number=Sing

# %%
sentence1[12].morph
# Out:
# Definite=Ind|PronType=Art

# %%
token2.pos_
# Out:
# 'NOUN'

# %%
token2.dep_
# Out:
# 'compound'

# %%
token2.lang_
# Out:
# 'en'

# %%
text = "Mike enjoys playing football."
doc2 = nlp(text)
print(doc2)
# Out:
# Mike enjoys playing football.

# %%
for token in doc2:
    print(token.text, token.pos_,token.dep_)
# Out:
# Mike PROPN nsubj
# enjoys VERB ROOT
# playing VERB xcomp
# football NOUN dobj
# . PUNCT punct

# %%
from spacy import displacy
displacy.render(doc2,style = 'dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b547d7c0aff74254a4186b786bb072b8-0" class="displacy" width="750" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mike</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">enjoys</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
# ...

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Quod PERSON
# Lorem PERSON
# Quibus ORG
# peti ORG
# Quae PERSON
# popularia GPE
# Duo Reges ORG
# Tum Lucius: PERSON
# quod ORG
# fratri PERSON
# Bestiarum PERSON
# Nihil enim iam habes PERSON
# quod ad corpus referas PERSON
# Deinde GPE
# congressu GPE
# inquit ORG
# huc GPE
# qui GPE
# animantibus ORG
# Quod PERSON
# Aristonem GPE
# Atqui GPE
# cum primae sint animi ORG
# secundae corporis PERSON
# Fieri GPE
# inquam GPE
# Triari GPE
# Equidem CARDINAL
# Dicet PERSON
# qua illum ORG
# P. Quod PERSON
# omnis historia ORG
# Quod PERSON
# quod te velle video ORG
# Ita NORP
# quanta conantur ORG
# qui audiunt GPE
# Vide ORG
# inquam GPE
# quod mihi PERSON
# videretur GPE
# nomina PERSON
# oculis se privasse PERSON
# quae GPE
# Quem PERSON
# Ciceronem PERSON
# sed etiam PERSON
# ipsum abducas licebit ORG
# Quae PERSON
# cum de rebus ORG
# grandioribus dicas PERSON
# Hoc PERSON
# Sed tu PERSON
# Latine ORG
# promptu GPE
# quam te ab istis ORG
# Fatebuntur Stoici PERSON
# ...

# %%
displacy.render(doc, style = "ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Quod
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  equidem non reprehendo;</br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lorem
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ipsum dolor sit amet, consectetur adipiscing elit.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Quibus
# ...

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
# 2022-03-25 07:23:44.993226: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-03-25 07:23:44.993273: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
nlp = spacy.load("en_core_web_md")

# %%
with open("sample3.txt","r") as f:
    text = f.read()

# %%
doc = nlp(text)
sentence1 = list(doc.sents)[0]
print(sentence1)
# Out:
# Quod equidem non reprehendo;
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.

# %%
import numpy as np

# %%
your_word = "country"

ms = nlp.vocab.vectors.most_similar(
    np.asarray([nlp.vocab.vectors[nlp.vocab.strings[your_word]]]), n=10)
words = [nlp.vocab.strings[w] for w in ms[0][0]]
distances = ms[2]
print(words)
# Out:
# ['country', 'COUNTRY', 'NATION', 'nation', 'COUNTIRES', 'nations', 'member-states', 'worLd', 'World', 'world']

# %%
doc1 = nlp("I like salty fries and hamburgers.")
doc2 = nlp("Fast food tastes very good.")

# %%
print(doc1,"<->",doc2, doc1.similarity(doc2))
# Out:
# I like salty fries and hamburgers. <-> Fast food tastes very good. 0.77994864211694

# %%
doc3 = nlp("The empire state building is in new york.")

# %%
print(doc1,"<->",doc3, doc1.similarity(doc3))
# Out:
# I like salty fries and hamburgers. <-> The empire state building is in new york. 0.51960369685646

# %%
doc4 = nlp("I enjoy oranges.")
doc5 = nlp("I enjoy apple.")

# %%
print(doc2,"<->",doc5, doc4.similarity(doc5))
# Out:
# Fast food tastes very good. <-> I enjoy apple. 0.9136869577792699

# %%
## Pipes

# %%
nlp = spacy.blank("en")

# %%
nlp.add_pipe("sentencizer")

# %%
import requests
from bs4 import BeautifulSoup
s = requests.get("n
                 ")
soup = BeautifulSoup(s.content).text.replace("-\n", "").replace("\n", " ")
nlp.max_length = 5278439
# Out:
#   File "<ipython-input-49-6b917ff535f4>", line 3
#     s = requests.get("n
#                        ^
# SyntaxError: EOL while scanning string literal

# %%
# %%time
doc = nlp(soup)
print (len(list(doc.sents)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'soup' is not defined

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'sentencizer': {'assigns': ['token.is_sent_start', 'doc.sents'],
#    'requires': [],
#    'scores': ['sents_f', 'sents_p', 'sents_r'],
#    'retokenizes': False}},
#  'problems': {'sentencizer': []},
#  'attrs': {'token.is_sent_start': {'assigns': ['sentencizer'], 'requires': []},
#   'doc.sents': {'assigns': ['sentencizer'], 'requires': []}}}

# %%
nlp2 = spacy.load("en_core_web_sm")

# %%
nlp2.analyze_pipes()
# Out:
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
#    'retokenizes': False}},
#  'problems': {'tok2vec': [],
#   'tagger': [],
# ...

# %%
## Entity Ruler

# %%
import spacy

#Build upon the spaCy Small Model
nlp = spacy.load("en_core_web_sm")

#Sample text
text = "The village of Treblinka is in Poland. Treblinka was also an extermination camp."

#Create the Doc object
doc = nlp(text)

#extract entities
for ent in doc.ents:
    print (ent.text, ent.label_)
# Out:
# Treblinka GPE
# Poland GPE

# %%
import spacy
import numpy as np
import pandas as pd

# %%
nlp = spacy.blank("en")

# %%
nlp.add_pipe("sentencizer")

# %%
nlp2 = spacy.load("en_core_web_sm")

# %%
import requests
from bs4 import BeautifulSoup
soup = request.get("https://ocw.mit.edu/ans7870/6/6.006/s08/lecturenotes/files/t8.shakespeare.txt")
soup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-9da64576778d> in <module>
# ----> 1 import requests3
#       2 from bs4 import BeautifulSoup
#       3 soup = request3.get("https://ocw.mit.edu/ans7870/6/6.006/s08/lecturenotes/files/t8.shakespeare.txt")
#       4 soup
#
# ModuleNotFoundError: No module named 'requests3'

# %%
pip install requests3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'sentencizer': {'assigns': ['token.is_sent_start', 'doc.sents'],
#    'requires': [],
#    'scores': ['sents_f', 'sents_p', 'sents_r'],
#    'retokenizes': False}},
#  'problems': {'sentencizer': []},
#  'attrs': {'doc.sents': {'assigns': ['sentencizer'], 'requires': []},
#   'token.is_sent_start': {'assigns': ['sentencizer'], 'requires': []}}}

# %%
nlp2.analyze_pipes()
# Out:
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
#    'retokenizes': False}},
#  'problems': {'tok2vec': [],
#   'tagger': [],
# ...

# %% [markdown]
# ## EntityRuler

# %%
nlp = spacy.load("en_core_web_sm")
text = "West Chestertenfieldville was referenced in Mr.Deeds."

# %%
doc = nlp(text)

# %%
print(doc)
# Out:
# West Chestertenfieldville was referenced in Mr.Deeds.

# %%
print(len(text))
print(len(doc))
# Out:
# 53
# 8

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# West Chestertenfieldville GPE
# Deeds PERSON

# %%
ruler = nlp.add_pipe("entity_ruler")

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
#    'retokenizes': False},
# ...

# %%
patterns = [
    {"label":"GPE","pattern":"West Chestertenfieldville",}
]

# %%
ruler.add_patterns(patterns)

# %%
doc2 = nlp(text)
for ent in doc2.ents:
    print(ent.text, ent.label_)
# Out:
# West Chestertenfieldville GPE
# Deeds PERSON

# %%
nlp2 = spacy.load("en_core_web_sm")

# %%
nlp2.add_pipe("entity_ruler",before = "ner")

# %%
ruler.add_patterns(patterns)

# %%
doc = nlp2(text)
# Out:
# C:\Users\Avi\anaconda3\lib\site-packages\spacy\pipeline\entityruler.py:394: UserWarning: [W036] The component 'entity_ruler' does not have any patterns defined.
#   warnings.warn(Warnings.W036.format(name=self.name))

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# West Chestertenfieldville GPE
# Deeds PERSON

# %%
nlp3 = spacy.load("en_core_web_sm")

# %%
ruler = nlp3.add_pipe("entity_ruler",before = "ner")

# %%
patterns = [
    {"label":"GPE","pattern":"West Chestertenfieldville"},
    {"label":"FILM","pattern":"Mr.Deeds"}
]

# %%
ruler.add_patterns(patterns)

# %%
doc = nlp3(text)

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# West Chestertenfieldville GPE
# Mr.Deeds FILM

# %% [markdown]
# ## Matcher

# %%
import spacy
from spacy.matcher import Matcher

# %%
nlp = spacy.load("en_core_web_sm")

# %%
matcher = Matcher(nlp.vocab)
pattern = [{"LIKE_EMAIL": True}]
matcher.add("EMAIL_ADDRESS",[pattern])

# %%
doc = nlp("This is an email address : wmattingly@aol.com")

# %%
matches = matcher(doc)

# %%
print(matches)
# Out:
# [(16571425990740197027, 6, 7)]

# %%
print(nlp.vocab[matches[0][0]].text)
# Out:
# EMAIL_ADDRESS

# %%
with open("alice.txt","r") as f:
    text = f.read()

# %%
print(text)
# Out:
# Alice's Adventures in Wonderland
#
#                 ALICE'S ADVENTURES IN WONDERLAND
#
#                           Lewis Carroll
#
#                THE MILLENNIUM FULCRUM EDITION 3.0
#
#
#
#
#                             CHAPTER I
#
#                       Down the Rabbit-Hole
#
#
#   Alice was beginning to get very tired of sitting by her sister
# on the bank, and of having nothing to do:  once or twice she had
# peeped into the book her sister was reading, but it had no
# pictures or conversations in it, `and what is the use of a book,'
# thought Alice `without pictures or conversation?'
#
#   So she was considering in her own mind (as well as she could,
# for the hot day made her feel very sleepy and stupid), whether
# the pleasure of making a daisy-chain would be worth the trouble
# of getting up and picking the daisies, when suddenly a White
# Rabbit with pink eyes ran close by her.
#
#   There was nothing so VERY remarkable in that; nor did Alice
# ...

# %%
nlp = spacy.load("en_core_web_sm")

# %%
matcher = Matcher(nlp.vocab)
pattern = [{"POS": "PROPN"}]
matcher.add("PROPER_NOUN",[pattern])
doc = nlp(text)
matches = matcher(doc)
print(len(matches))
for match in matches[:10]:
    print(match,doc[match[1]:match[2]])
# Out:
# 1489
# (451313080118390996, 0, 1) Alice
# (451313080118390996, 2, 3) Adventures
# (451313080118390996, 4, 5) Wonderland
# (451313080118390996, 6, 7) ALICE
# (451313080118390996, 8, 9) ADVENTURES
# (451313080118390996, 10, 11) WONDERLAND
# (451313080118390996, 12, 13) Lewis
# (451313080118390996, 13, 14) Carroll
# (451313080118390996, 16, 17) MILLENNIUM
# (451313080118390996, 26, 27) Rabbit

# %%
matcher = Matcher(nlp.vocab)
pattern = [{"POS": "PROPN","OP":"+"},{"POS":"VERB"}]
matcher.add("PROPER_NOUN",[pattern],greedy = "LONGEST")
doc = nlp(text)
matches = matcher(doc)
matches.sort(key = lambda x:x[1])
print(len(matches))
for match in matches[:10]:
    print(match,doc[match[1]:match[2]])
# Out:
# 268
# (451313080118390996, 196, 198) Rabbit say
# (451313080118390996, 278, 280) Alice started
# (451313080118390996, 402, 404) Alice had
# (451313080118390996, 828, 830) Alice had
# (451313080118390996, 1055, 1057) Dinah'll miss
# (451313080118390996, 1157, 1159) Alice began
# (451313080118390996, 1659, 1661) Alice opened
# (451313080118390996, 2132, 2134) Alice ventured
# (451313080118390996, 3477, 3480) White Rabbit returning
# (451313080118390996, 3548, 3550) Alice felt

# %%
import json
with open("hp_characters.json","r") as f:
    data = json.load(f)

# %%
text = data[0][1][0]
print(text)
# Out:
# a

# %%
text = text.replace(" ","'")
print(text)
# Out:
# a

# %%
matcher = Matcher(nlp.vocab)
pattern = [{"POS": "PROPN"}]
matcher.add("PROPER_NOUN",[pattern])
doc = nlp(text)
matches = matcher(doc)
print(len(matches))
for match in matches[:10]:
    print(match,doc[match[1]:match[2]])

# %% [markdown]
# ## Custom Components in SpaCy

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_lg")
doc = nlp("Britain is a place. Mary is a doctor")

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Britain GPE
# Mary PERSON

# %%
from spacy.language import Language

# %%
@Language.component("remove_gpe")
def remove_gpe(doc):
    original_ents = list(doc.ents)
    for ent in doc.ents:
        if ent.label_ == "GPE":
            original_ents.remove(ent)
        doc.ents = original_ents
        return(doc)

# %%
nlp.add_pipe("remove_gpe")
# Out:
# <function __main__.remove_gpe(doc)>

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
#    'retokenizes': False},
#   'remove_gpe': {'assigns': [],
#    'requires': [],
# ...

# %%
doc = nlp("Britain is a place. Mary is a doctor.")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Britain GPE
# Mary PERSON

# %% [markdown]
# ## RegEx

# %%
import re

# %%
text = "Paul Newman was an American actor, but Paul Hollywood is British Tv Host. The name Paul is quite common."

# %%
pattern = r"Paul [A-Z]\w+"

# %%
matches = re.finditer(pattern, text)

# %%
for match in matches:
    print(match
         )
# Out:
# <re.Match object; span=(0, 11), match='Paul Newman'>
# <re.Match object; span=(39, 53), match='Paul Hollywood'>

# %%
import spacy
from spacy.tokens import Span

# %%
nlp = spacy.blank("en")
doc  = nlp(text)
print(doc.ents)
original_ents  = list(doc.ents)
nwt_ents = []
for match in re.finditer(pattern, doc.text):
    start,end = match.span()
    span = doc.char_span(start,end)
    if span is not None:
        nwt_ents.append((span.start, span.end,span.text))
for ent in nwt_ents:
    start,end,name = ent
    per_ent = Span(doc, start, end, label = "PERSON")
    original_ents.append(per_ent)
doc.ents = original_ents
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# ()
# Paul Newman PERSON
# Paul Hollywood PERSON

# %%
print(nwt_ents)
# Out:
# [(0, 2, 'Paul Newman'), (8, 10, 'Paul Hollywood')]

# %%
from spacy.language import Language

@Language.component("paul_ner")
def paul_ner(doc):
    pattern = r"Hollywood"
    print(doc.ents)
    original_ents  = list(doc.ents)
    nwt_ents = []
    for match in re.finditer(pattern, doc.text):
        start,end = match.span()
        span = doc.char_span(start,end)
        if span is not None:
            nwt_ents.append((span.start, span.end,span.text))
    for ent in nwt_ents:
        start,end,name = ent
        per_ent = Span(doc, start, end, label = "CINEMA")
        original_ents.append(per_ent)
    doc.ents = original_ents
    return(doc)

# %%
nlp3 = spacy.load("en_core_web_lg")
nlp3.add_pipe("cinema_per")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-8376d3aada88> in <module>
#       1 nlp3 = spacy.load("en_core_web_lg")
# ----> 2 nlp3.add_pipe("cinema_per")
#
# ~\anaconda3\lib\site-packages\spacy\language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     790                     lang_code=self.lang,
#     791                 )
# --> 792             pipe_component = self.create_pipe(
#     793                 factory_name,
#     794                 name=name,
#
# ~\anaconda3\lib\site-packages\spacy\language.py in create_pipe(self, factory_name, name, config, raw_config, validate)
#     653                 lang_code=self.lang,
#     654             )
# --> 655             raise ValueError(err)
#     656         pipe_meta = self.get_factory_meta(factory_name)
# ...

# %%
nlp2 = spacy.blank("en")
nlp2.add_pipe("paul_ner")
# Out:
# <function __main__.paul_ner(doc)>

# %%
doc2 = nlp2(text)
print(doc2.ents)
# Out:
# ()
# (Hollywood,)
