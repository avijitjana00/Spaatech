# %%
#!pip install tika

# %%
from tika import parser
file = 'Avijit_CV.pdf'
file_data = parser.from_file(file)
text = file_data['content']
print(text)
# Out:
# 2022-04-18 20:19:30,960 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# 2022-04-18 20:19:36,028 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# fcdabce8-b2f0-4992-b91f-822903ff67ab.pdf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  AVIJIT JANA
#            Aspiring Data Scientist
#
#
#
# CAREER OBJECTIVE:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Functional knowledge of OOPs, JAVA, PYTHON, EDA, FLASK API.
#
#  Knowledge on different Machine Learning technique like – Supervised, Unsupervised,
#
# Ensemble Technique.
#
#  Working Experience & Extensive knowledge in python with libraries such as Numpy,
#
# Pandas, Matplotlib, Seaborn, Sklearn.
#
#  Seeking a challenging position in a reputed organization where I can learn new skills,
#
# expand my knowledge and leverage my learnings.
#
#  To get an opportunity where I can make the best of my potential and contribute to the
#
# organization’s growth.
#
#  A highly motivated and hardworking individual looking for a responsible role in a
#
# reputable organization.
#
#  Fluent communication skills and good team working skill.
#
#
#
# EDUCATIONAL QUALIFICATION:
#
#
# Course/Degree Institute Board/ University Marks Year of
#
# Passing
#
# MSC IN IT
#
# (DATA
#
# SCIENCE)
#
# MAULANA ABUL
#
# KALAM AZAD
#
# UNIVERSITY OF
#
# TECHNOLOGY,
#
# WEST BENGAL
#
# MAULANA ABUL
#
# KALAM AZAD
#
# UNIVERSITY OF
#
# TECHNOLOGY,
#
# West Bengal
#
# 9.4
#
# (Up to 2
#
# semester)
#
# Due to
#
# Appear
#
# B.SC(H) PANSKURA VIDYASAGAR
# 2020 (COMPUTER BANAMALI UNIVERCITY, 73.8%
#
# SCIENCE) COLLEGE, WEST BENGAL (CGPA-
#
#  PANSKURA, WEST
# BENGAL
#
#  7.38)
#
# HIGHER
#
# SECONDARY
#
# SHYAMSUNDAR
#
# PUR PATNA
#
# HIGH SCHOOL,
#
# West Bengal
#
# Board Of
#
# Higher
#
#
#
#
# 65.8%
#
# 2017
#
# PURBA MEDINIUR, Secondary
#
# Ph. No: +919547850091
#
# E-mail: avijitjana002016@gmail.com
#
# Panskura,, Purba medinipur
#
# West Bengal -721139
# Linkedin : https://www.linkedin.com/in/avijit-jana-4a1165203/
#
# GitHub : https://github.com/avijitjana00
#
#
#
#
#
#
#
# WEST BANGAL Education
#
# 10th LEVEL SHYAMSUNDARPU
# R PATNA HIGH
# SCHOOL,
#
# West Bengal
#
#
#
#
# 67%
#
# 2015
#
# PURBA MEDINIUR, Board Of
#
# WEST
#
# BANGAL
#
# Secondary
#
# Education
#
# TECHNICAL SKILLS:
#
#
# Core Skills               :                           Java, Python
#
# RDMS                      :                           MySQL,
#
# BIG DATA              :                           MongoDB
#
# TYPING SKILLS    :                           38 WPM
#
#
#
# OTHER SKILLS:
#
#
# • Leadership skills
#
# • Adaptability
#
# • Ability to work under pressure
#
# • Seeking excellence
#
# HOBBIES:
# • Love to play cricket
# • Write short story and Poem
# • like to cook
#
# Internship Details
# • Data Science Intern | Exposys Data Labs | Jan 2022 – Feb 2022
# • Team lead -  Y Vishnuvardhan.
# • Project – end to end data science project with deployment | create a web-api.
# • Project goal – to investigate a machine learning techniques to predict a patient diabetic or
#
# not.
#
# • Result – Fund that Random Forest performed best accuracy for predicting model.
#
# ACADEMIC EXPERIENCE :
#  May 2021 to till date                                  Organization : MAKAUT
#
#
# Role: Data Analysis
# Technology/Application: Python/R, Power BI
#
# Contribution: Data Cleaning, Data Preparation, Exploratory Data Analysis
#
#
#
# PERSONAL INFORMATION:
# Date of Birth: 24th OCTOBER 1998.
#
# Fathers Name: Kamalesh Jana
#
#
#
# References: Available upon request

# %%
parsed_content = {}

# %%
import re
def get_email_addresses(string):
    r = re.compile(r'[\w\.-]+@[\w\.-]+')
    return r.findall(string)

email = get_email_addresses(text)
print(email)
parsed_content['E-mail'] = email
# Out:
# ['avijitjana002016@gmail.com']

# %%
import re
def get_phone_numbers(string):
    r = re.compile(r'(\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4})')
    phone_numbers = r.findall(string)
    return [re.sub(r'\D', '', num) for num in phone_numbers]

phone_number= get_phone_numbers(text)
if len(phone_number) <= 10:
    print(phone_number)
    parsed_content['Phone number'] = phone_number
# Out:
# ['9195478500', '1165203']

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

def extract_name(text):
    nlp_text = nlp(text)
  
   # First name and Last name are always Proper Nouns
    pattern = [{'POS': 'PROPN'}, {'POS': 'PROPN'}]
  
    matcher.add('NAME', [pattern], on_match = None)
  
    matches = matcher(nlp_text)
  
    for match_id, start, end in matches:
        span = nlp_text[start:end]
        return span.text

name = extract_name(text)
print(name)
parsed_content['Name'] =  name
# Out:
# AVIJIT JANA

# %%
Keywords = ["education",
            "summary",
            "accomplishments",
            "executive profile",
            "professional profile",
            "personal profile",
            "work background",
            "academic profile",
            "other activities",
            "qualifications",
            "experience",
            "interests",
            "skills",
            "achievements",
            "publications",
            "publication",
            "certifications",
            "workshops",
            "projects",
            "internships",
            "trainings",
            "hobbies",
            "overview",
            "objective",
            "position of responsibility",
            "jobs"
           ]

# %%
text = text.replace("\n"," ")
text = text.replace("[^a-zA-Z0-9]", " ");  
re.sub('\W+','', text)
text = text.lower()
print(text)
# Out:
#                                               fcdabce8-b2f0-4992-b91f-822903ff67ab.pdf                       avijit jana             aspiring data scientist       career objective:                            functional knowledge of oops, java, python, eda, flask api.    knowledge on different machine learning technique like – supervised, unsupervised,   ensemble technique.    working experience & extensive knowledge in python with libraries such as numpy,   pandas, matplotlib, seaborn, sklearn.    seeking a challenging position in a reputed organization where i can learn new skills,   expand my knowledge and leverage my learnings.    to get an opportunity where i can make the best of my potential and contribute to the   organization’s growth.    a highly motivated and hardworking individual looking for a responsible role in a   reputable organization.    fluent communication skills and good team working skill.      educational qualification:     course/degree institute board/ university marks year of   passing   msc in it   (data   science)   maulana abul   kalam azad   university of   technology,   west bengal   maulana abul   kalam azad   university of   technology,   west bengal   9.4   (up to 2   semester)   due to   appear   b.sc(h) panskura vidyasagar    2020 (computer banamali univercity, 73.8%   science) college, west bengal (cgpa-    panskura, west  bengal    7.38)   higher   secondary   shyamsundar  pur patna   high school,   west bengal   board of   higher        65.8%   2017   purba mediniur, secondary   ph. no: +919547850091                                                                                e-mail: avijitjana002016@gmail.com   panskura,, purba medinipur   west bengal -721139  linkedin : https://www.linkedin.com/in/avijit-jana-4a1165203/   github : https://github.com/avijitjana00           west bangal education   10th level shyamsundarpu r patna high  school,   west bengal         67%   2015   purba mediniur, board of   west   bangal   secondary   education   technical skills:     core skills               :                           java, python   rdms                      :                           mysql,   big data              :                           mongodb   typing skills    :                           38 wpm      other skills:     • leadership skills   • adaptability   • ability to work under pressure   • seeking excellence   hobbies:  • love to play cricket  • write short story and poem  • like to cook   internship details  • data science intern | exposys data labs | jan 2022 – feb 2022  • team lead -  y vishnuvardhan.  • project – end to end data science project with deployment | create a web-api.  • project goal – to investigate a machine learning techniques to predict a patient diabetic or   not.   • result – fund that random forest performed best accuracy for predicting model.   academic experience :   may 2021 to till date                                  organization : makaut     role: data analysis  technology/application: python/r, power bi   contribution: data cleaning, data preparation, exploratory data analysis      personal information:  date of birth: 24th october 1998.   fathers name: kamalesh jana      references: available upon request

# %%
content = {}
indices = []
keys = []
for key in Keywords:
    try:
        content[key] = text[text.index(key) + len(key):]
        indices.append(text.index(key))
        keys.append(key)
    except:
        pass

# %%
zipped_lists = zip(indices, keys)
sorted_pairs = sorted(zipped_lists)
sorted_pairs

tuples = zip(*sorted_pairs)
indices, keys = [ list(tuple) for tuple in  tuples]
keys
# Out:
# ['objective', 'experience', 'skills', 'education', 'hobbies']

# %%
content = []
for idx in range(len(indices)):
    if idx != len(indices)-1:
        content.append(text[indices[idx]: indices[idx+1]])
    else:
        content.append(text[indices[idx]: ])

# %%
for i in range(len(indices)):
    parsed_content[keys[i]] = content[i]

# %%
parsed_content
# Out:
# {'E-mail': ['avijitjana002016@gmail.com'],
#  'Phone number': ['9195478500', '1165203'],
#  'Name': 'AVIJIT JANA',
#  'objective': 'objective:                           \uf0a8 functional knowledge of oops, java, python, eda, flask api.   \uf0a8 knowledge on different machine learning technique like – supervised, unsupervised,   ensemble technique.   \uf0a8 working ',
#  'experience': 'experience & extensive knowledge in python with libraries such as numpy,   pandas, matplotlib, seaborn, sklearn.   \uf0a8 seeking a challenging position in a reputed organization where i can learn new ',
#  'skills': 'skills,   expand my knowledge and leverage my learnings.   \uf0a8 to get an opportunity where i can make the best of my potential and contribute to the   organization’s growth.   \uf0a8 a highly motivated and hardworking individual looking for a responsible role in a   reputable organization.   \uf0a8 fluent communication skills and good team working skill.      ',
#  'education': 'educational qualification:     course/degree institute board/ university marks year of   passing   msc in it   (data   science)   maulana abul   kalam azad   university of   technology,   west bengal   maulana abul   kalam azad   university of   technology,   west bengal   9.4   (up to 2   semester)   due to   appear   b.sc(h) panskura vidyasagar    2020 (computer banamali univercity, 73.8%   science) college, west bengal (cgpa-    panskura, west  bengal    7.38)   higher   secondary   shyamsundar  pur patna   high school,   west bengal   board of   higher        65.8%   2017   purba mediniur, secondary   ph. no: +919547850091                                                                                e-mail: avijitjana002016@gmail.com   panskura,, purba medinipur   west bengal -721139  linkedin : https://www.linkedin.com/in/avijit-jana-4a1165203/   github : https://github.com/avijitjana00           west bangal education   10th level shyamsundarpu r patna high  school,   west bengal         67%   2015   purba mediniur, board of   west   bangal   secondary   education   technical skills:     core skills               :                           java, python   rdms                      :                           mysql,   big data              :                           mongodb   typing skills    :                           38 wpm      other skills:     • leadership skills   • adaptability   • ability to work under pressure   • seeking excellence   ',
#  'hobbies': 'hobbies:  • love to play cricket  • write short story and poem  • like to cook   internship details  • data science intern | exposys data labs | jan 2022 – feb 2022  • team lead -  y vishnuvardhan.  • project – end to end data science project with deployment | create a web-api.  • project goal – to investigate a machine learning techniques to predict a patient diabetic or   not.   • result – fund that random forest performed best accuracy for predicting model.   academic experience :   may 2021 to till date                                  organization : makaut     role: data analysis  technology/application: python/r, power bi   contribution: data cleaning, data preparation, exploratory data analysis      personal information:  date of birth: 24th october 1998.   fathers name: kamalesh jana      references: available upon request   '}

# %%
import json
with open("Parsed_Resume.json", "w") as outfile:
    json.dump(parsed_content, outfile)

# %%
a_file = open("Parsed_Resume.json", "r")
a_json = json.load(a_file)
pretty_json = json.dumps(a_json, indent=4)
a_file.close()
print(pretty_json)
# Out:
# {
#     "E-mail": [
#         "avijitjana002016@gmail.com"
#     ],
#     "Phone number": [
#         "9195478500",
#         "1165203"
#     ],
#     "Name": "AVIJIT JANA",
#     "objective": "objective:                           \uf0a8 functional knowledge of oops, java, python, eda, flask api.   \uf0a8 knowledge on different machine learning technique like \u2013 supervised, unsupervised,   ensemble technique.   \uf0a8 working ",
#     "experience": "experience & extensive knowledge in python with libraries such as numpy,   pandas, matplotlib, seaborn, sklearn.   \uf0a8 seeking a challenging position in a reputed organization where i can learn new ",
#     "skills": "skills,   expand my knowledge and leverage my learnings.   \uf0a8 to get an opportunity where i can make the best of my potential and contribute to the   organization\u2019s growth.   \uf0a8 a highly motivated and hardworking individual looking for a responsible role in a   reputable organization.   \uf0a8 fluent communication skills and good team working skill.      ",
#     "education": "educational qualification:     course/degree institute board/ university marks year of   passing   msc in it   (data   science)   maulana abul   kalam azad   university of   technology,   west bengal   maulana abul   kalam azad   university of   technology,   west bengal   9.4   (up to 2   semester)   due to   appear   b.sc(h) panskura vidyasagar    2020 (computer banamali univercity, 73.8%   science) college, west bengal (cgpa-    panskura, west  bengal    7.38)   higher   secondary   shyamsundar  pur patna   high school,   west bengal   board of   higher        65.8%   2017   purba mediniur, secondary   ph. no: +919547850091                                                                                e-mail: avijitjana002016@gmail.com   panskura,, purba medinipur   west bengal -721139  linkedin : https://www.linkedin.com/in/avijit-jana-4a1165203/   github : https://github.com/avijitjana00           west bangal education   10th level shyamsundarpu r patna high  school,   west bengal         67%   2015   purba mediniur, board of   west   bangal   secondary   education   technical skills:     core skills               :                           java, python   rdms                      :                           mysql,   big data              :                           mongodb   typing skills    :                           38 wpm      other skills:     \u2022 leadership skills   \u2022 adaptability   \u2022 ability to work under pressure   \u2022 seeking excellence   ",
#     "hobbies": "hobbies:  \u2022 love to play cricket  \u2022 write short story and poem  \u2022 like to cook   internship details  \u2022 data science intern | exposys data labs | jan 2022 \u2013 feb 2022  \u2022 team lead -  y vishnuvardhan.  \u2022 project \u2013 end to end data science project with deployment | create a web-api.  \u2022 project goal \u2013 to investigate a machine learning techniques to predict a patient diabetic or   not.   \u2022 result \u2013 fund that random forest performed best accuracy for predicting model.   academic experience :   may 2021 to till date                                  organization : makaut     role: data analysis  technology/application: python/r, power bi   contribution: data cleaning, data preparation, exploratory data analysis      personal information:  date of birth: 24th october 1998.   fathers name: kamalesh jana      references: available upon request   "
# }
